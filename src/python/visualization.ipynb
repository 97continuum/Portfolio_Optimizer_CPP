# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
columns = [f"Asset {i}" for i in range(1, 84)]

# %%
data = pd.read_csv("Desktop/Code/Portfolio_Optimizer_CPP/data/asset_returns.csv",
                   header=None, 
                   names = columns,
                   index_col=False)

# %%
data
# Out:
#       Asset 1   Asset 2   Asset 3   Asset 4   Asset 5   Asset 6   Asset 7  \
# 0   -0.005763 -0.026772 -0.087660  0.026042 -0.003650 -0.074595 -0.057377
# 1    0.058059  0.113269  0.175373  0.096116  0.076657  0.120327  0.010870
# 2   -0.037039  0.035610 -0.026984 -0.077318 -0.144086 -0.012513 -0.053763
# 3    0.055546 -0.002807  0.093801  0.044626  0.089131  0.062302  0.011364
# 4    0.037787  0.035890  0.021626  0.163150  0.064524  0.053678  0.024719
# ..        ...       ...       ...       ...       ...       ...       ...
# 695 -0.030895 -0.008481 -0.039122  0.031709 -0.028942 -0.036461  0.012989
# 696  0.046157  0.034215  0.023212  0.004294  0.032722  0.032822  0.000871
# 697 -0.010095 -0.000258  0.008181  0.009226  0.014127  0.011819  0.002861
# 698 -0.014920 -0.008402 -0.023608 -0.027871 -0.028657 -0.097729 -0.000372
# 699 -0.052627 -0.064007 -0.032867 -0.065367 -0.075190 -0.052647 -0.006203
#
#       Asset 8   Asset 9  Asset 10  ...  Asset 74  Asset 75  Asset 76  \
# ...

# %%
data.describe()
# Out:
#           Asset 1     Asset 2     Asset 3     Asset 4     Asset 5     Asset 6  \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     0.000411    0.002837    0.000577    0.001840    0.001710    0.000173
# std      0.037389    0.026777    0.030229    0.036122    0.051412    0.036287
# min     -0.215655   -0.132044   -0.112062   -0.131061   -0.222043   -0.173948
# 25%     -0.017362   -0.012756   -0.016471   -0.018125   -0.022199   -0.018352
# 50%     -0.001245    0.002759    0.000000    0.000282    0.003203   -0.000725
# 75%      0.017239    0.018942    0.017609    0.021755    0.027967    0.019744
# max      0.266465    0.113269    0.175373    0.203054    0.402580    0.196970
#
#           Asset 7     Asset 8     Asset 9    Asset 10  ...    Asset 74  \
# count  700.000000  700.000000  700.000000  700.000000  ...  700.000000
# mean     0.003670    0.000580    0.001554    0.000333  ...    0.001906
# ...

# %%
results = pd.read_csv("Desktop/Code/Portfolio_Optimizer_CPP/data/results.csv", header=0)

# %%
results
# Out:
#     Target Returns  Backtest Period: 1  Backtest Period: 2  \
# 0            0.005            0.006420            0.006946
# 1            0.010            0.011923            0.009702
# 2            0.015            0.016723            0.012226
# 3            0.020            0.020790            0.014323
# 4            0.025            0.025736            0.016988
# 5            0.030            0.031773            0.013245
# 6            0.035            0.036754            0.014671
# 7            0.040            0.041738            0.015564
# 8            0.045            0.053367            0.014894
# 9            0.050            0.059123            0.016069
# 10           0.055            0.065994            0.017254
# 11           0.060            0.071607            0.018386
# 12           0.065            0.077529            0.010882
# 13           0.070            0.083370            0.011282
# 14           0.075            0.088916            0.011702
# ...

# %%
results.mean(axis=1)
# Out:
# 0     0.002164
# 1     0.002997
# 2     0.003563
# 3     0.003928
# 4     0.004471
# 5     0.005055
# 6     0.005886
# 7     0.006508
# 8     0.007642
# 9     0.009304
# 10    0.010204
# 11    0.010461
# 12    0.010321
# 13    0.012172
# 14    0.012046
# 15    0.012700
# 16    0.013847
# 17    0.014584
# 18    0.014438
# 19    0.015286
# dtype: float64
